# %%
import random

# %%
play_game = 'y'
start = 1
end = 100
direction = 'N'
smallest = start
largest = end
while play_game == 'y':
    smallest = start
    largest = end
    print('guess a number between 1 an 100: ')
    try_number = random.randint(smallest,largest)
    print(try_number)
    counter = 0
    direction = 'N'
    while direction != 'C':
        direction = input('is it too large(L), too small(S), correct(C)? ')
        if direction == 'S':
            if try_number > smallest:
                smallest = try_number + 1
                try_number = random.randint(smallest,largest)
                print(try_number)
        if direction == 'L':
            if try_number < largest:
                largest = try_number - 1
                try_number = random.randint(smallest,largest)
                print(try_number)
        counter = counter + 1
    print('i got it! i tried ' + str(counter) + ' times')
    play_game = input('yes or no: ')
# Out:
# guess a number between 1 an 100:
# 2
# is it too large(L), too small(S), correct(C)? S
# 75
# is it too large(L), too small(S), correct(C)? L
# 35
# is it too large(L), too small(S), correct(C)? S
# 39
# is it too large(L), too small(S), correct(C)? S
# 57
# is it too large(L), too small(S), correct(C)? S
# 69
# is it too large(L), too small(S), correct(C)? L
# 60
# is it too large(L), too small(S), correct(C)? C
# i got it! i tried 7 times
# yes or no: n
